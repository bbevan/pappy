# %%
from Fourier2 import Fourier2 as pappy

# %%
z = pappy("science_z.gif")
z1 = pappy("graffiti.jpg")

# %%
z.view()

# %%
z.viewphase()

# %%
z.viewfrequency()

# %%
z.viewinverse()

# %%
z1.view()
